# %%
# Importing cv2 module
import cv2
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread('a.jpg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=256x324 at 0x7FA3F2748910>

# %%
blurImg = cv2.blur(img,(3,3))
cv2_imshow(blurImg)
# Out:
# <PIL.Image.Image image mode=RGB size=256x324 at 0x7FA3F2748910>
